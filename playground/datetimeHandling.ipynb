# %%
import numpy as np
import pandas as pd
from datetime import *

# %%
now = datetime.now(timezone.utc)
print(now)
# Out:
# 2024-09-28 08:21:32.254685+00:00

# %%
date1 = '2024-09-26 12:00:00'
date1 = datetime.strptime(date1, '%Y-%m-%d %H:%M:%S')
print(date1, type(date1))
# Out:
# 2024-09-26 12:00:00 <class 'datetime.datetime'>

# %%
date1_utc = date1.astimezone(timezone.utc)

# %%
print(date1)
# Out:
# 2024-09-26 12:00:00

# %%
print(now_utc.tzinfo)
print(now.tzinfo)
# Out:
# None
# UTC

# %%
print(now, now_utc)
# Out:
# 2024-09-28 08:21:32.254685+00:00 2024-09-28 08:17:22.293166

# %%
delta = (now - date1_utc)
print(delta, type(delta))
# Out:
# 2 days, 4:21:32.254685 <class 'datetime.timedelta'>

# %%
delta_ss = (now-date1_utc).seconds
print(delta_ss)
# Out:
# 15692

# %%
delta_1h = delta_ss/3600
print(delta_1h)
# Out:
# 4.358888888888889

# %%
date1_naive = datetime(2024, 1, 1, 12, 0, 0)  # offset-naive
date2_utc = datetime(2024, 1, 10, 12, 0, 0, tzinfo=timezone.utc)

# %%
date1_utc = date1_naive.replace(tzinfo=timezone.utc)

# %%
print(date1_utc)
# Out:
# 2024-01-01 12:00:00+00:00

# %%
print(date2_utc)
# Out:
# 2024-01-10 12:00:00+00:00

# %%
delta = (datetime.now(timezone.utc) - date1_utc).seconds
print(delta, type(delta))
delta_1h = delta/3600
print(delta_1h)
# Out:
# 74288 <class 'int'>
# 20.635555555555555

# %%
lasted_h = (date2_utc-date1_utc).total_seconds()/3600
print(lasted_h)
# Out:
# 216.0

# %%
lasted_d = (date2_utc-date1_utc).days
print(lasted_d)
# Out:
# 9

# %%
216/24
# Out:
# 9.0

# %%
15*60
# Out:
# 900

# %%
import math
num = math.floor(14.9)
print(type(num))
# Out:
# <class 'int'>
