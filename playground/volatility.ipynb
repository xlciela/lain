# %%
import pandas as pd

# %%
import numpy as np

# %%
import talib.abstract as ta

# %%
df = pd.read_csv('bitcoin.csv')
tdf = df.tail(200)

# %%
tdf.columns = [col.lower() for col in tdf.columns]

# %%
tv = (tdf['high'] - tdf['low']).values

# %%
tv
# Out:
# array([1006.12,  516.3 ,  353.61,  654.76,  339.27,  300.38,  326.77,
#         442.02,  370.37,  230.69,  733.79,  290.  ,  222.24,  630.  ,
#         407.3 ,  382.27,  447.59,  358.46,  378.96,  343.94,  393.71,
#         284.37, 1010.2 ,  945.97,  514.09,  594.59,  397.18,  266.72,
#         317.49,  232.83,  661.94,  332.49,  601.35,  360.23,  770.22,
#         513.83,  358.51,  563.34,  398.14,  493.31,  782.39,  616.37,
#         672.47,  424.83,  284.75,  310.  ,  397.37,  386.33,  511.86,
#         327.72,  259.25,  407.6 ,  319.56,  919.74,  299.  ,  232.71,
#        2957.3 ,  701.84,  715.88,  422.85,  583.85,  450.77,  617.02,
#         302.99,  490.14,  484.32,  461.43,  367.41,  784.99,  261.01,
#         613.25,  421.17,  245.66,  346.02,  286.72,  342.97,  237.9 ,
#         160.92,  258.28,  233.01,  232.05,  256.5 ,  168.2 ,  706.49,
#         333.01,  244.48,  366.21,  238.06,  208.35,  402.99,  394.41,
# ...

# %%
type(tv)
# Out:
# numpy.ndarray

# %%
smooth_tv = ta.EMA(tv, 5)

# %%
tdf['smooth_tv'] = smooth_tv
tdf
# Out:
# C:\Users\xlfin\AppData\Local\Temp\ipykernel_23224\166666656.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tdf['smooth_tv'] = smooth_tv
#                       date      open      high       low     close  \
# 35968  2021-09-29 00:00:00  41025.01  41760.00  40753.88  41596.20
# 35969  2021-09-29 01:00:00  41596.21  41850.30  41334.00  41551.15
# 35970  2021-09-29 02:00:00  41551.15  41897.98  41544.37  41701.80
# 35971  2021-09-29 03:00:00  41701.81  42274.76  41620.00  42199.99
# 35972  2021-09-29 04:00:00  42199.99  42476.26  42136.99  42245.80
# ...                    ...       ...       ...       ...       ...
# 36163  2021-10-07 05:00:00  55073.20  55073.21  54545.07  54735.76
# ...
